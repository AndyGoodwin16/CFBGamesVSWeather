# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("data/cfb_attendance.csv", encoding = "cp1252")
df
# Out:
#           Date      Team      Time                   Opponent Rank  \
# 0       9/2/00  Arkansas   8:00 PM  Southwest Missouri State*   NR
# 1      9/16/00  Arkansas   6:00 PM               Boise State*   NR
# 2      9/23/00  Arkansas   8:00 PM                    Alabama   NR
# 3      9/30/00  Arkansas  11:30 AM             No. 25 Georgia   NR
# 4      10/7/00  Arkansas   6:00 PM          Louisiana–Monroe*   NR
# ...        ...       ...       ...                        ...  ...
# 6667   9/22/18      UTEP   5:30 PM          New Mexico State*   NR
# 6668   10/6/18      UTEP   5:30 PM                North Texas   NR
# 6669  10/27/18      UTEP   5:30 PM                        UAB   NR
# 6670  11/10/18      UTEP   1:00 PM           Middle Tennessee   NR
# 6671  11/24/18      UTEP   1:00 PM              Southern Miss   NR
#
#                                       Site         TV   Result  Attendance  \
# 0      War Memorial StadiumLittle Rock, AR  Not on TV   W 38–0       53946
# ...

# %%
df[['Result', 'Win/Loss', 'OT']] = df.["Result".]str.split?
# Out:
# Signature: str.split(self, /, sep=None, maxsplit=-1)
# Docstring:
# Return a list of the words in the string, using sep as the delimiter string.
#
# sep
#   The delimiter according which to split the string.
#   None (the default value) means split according to any whitespace,
#   and discard empty strings from the result.
# maxsplit
#   Maximum number of splits to do.
#   -1 (the default value) means no limit.
# Type:      method_descriptor

# %%
df[['Result', 'Win/Loss', 'OT']] = df.["Result".]str.split

# %%
df[['Result', 'Win/Loss', 'OT']] = df.["Result".]str.split

# %%
df[['Result', 'Win/Loss', 'OT']] = df.Result.str.split
